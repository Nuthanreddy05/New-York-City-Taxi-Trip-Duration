# %%
import pandas as pd
import numpy as np

# %%
# Load the dataset
df = pd.read_csv("/Users/nuthanreddyvaddireddy/Desktop/train.csv")
# Set the random seed with last 4 digits of id card
np.random.seed(5133)
# Sample 100,000 rows
df = df.sample(n=100000)
df
# Out:
#                 id  vendor_id      pickup_datetime     dropoff_datetime  \
# 1105621  id3077574          2  2016-05-13 08:45:14  2016-05-13 08:50:11
# 906647   id2660233          1  2016-04-21 09:21:30  2016-04-21 09:24:58
# 457894   id2990246          2  2016-01-07 22:17:27  2016-01-07 22:28:19
# 1427706  id1330110          1  2016-05-03 19:27:47  2016-05-03 19:42:26
# 79507    id2910334          2  2016-06-04 15:00:27  2016-06-04 15:15:23
# ...            ...        ...                  ...                  ...
# 238151   id2258604          2  2016-04-19 13:49:32  2016-04-19 14:02:29
# 589999   id1030782          2  2016-05-14 04:17:56  2016-05-14 04:20:05
# 312141   id2410744          1  2016-03-18 13:23:46  2016-03-18 13:26:33
# 947441   id2174373          1  2016-02-15 12:41:36  2016-02-15 12:47:54
# 1293649  id1367927          1  2016-06-05 12:47:48  2016-06-05 12:53:20
#
#          passenger_count  pickup_longitude  pickup_latitude  \
# ...

# %% [markdown]
# # 1.Data Pre-processing:

# %% [markdown]
# ### Provide summary statistics for the dataset.

# %%
#summary statistics for the dataset.
summary = df.describe()
summary
# Out:
#            vendor_id  passenger_count  pickup_longitude  pickup_latitude  \
# count  100000.000000    100000.000000     100000.000000    100000.000000
# mean        1.537760         1.668260        -73.973466        40.750920
# std         0.498575         1.320623          0.042385         0.031886
# min         1.000000         0.000000        -78.547401        36.029301
# 25%         1.000000         1.000000        -73.991783        40.737460
# 50%         2.000000         1.000000        -73.981659        40.754230
# 75%         2.000000         2.000000        -73.967237        40.768375
# max         2.000000         6.000000        -73.553223        41.256882
#
#        dropoff_longitude  dropoff_latitude  trip_duration
# count      100000.000000     100000.000000  100000.000000
# mean          -73.973436         40.751833     944.415930
# std             0.046791          0.036578    3020.231686
# min           -79.817978         36.029301       1.000000
# ...

# %% [markdown]
# By using the df.describe() function we get the complete summary statistics of the data like including the count, mean, standard deviation, minimum, 25th percentile (first quartile), median (50th percentile or second quartile), 75th percentile (third quartile), and maximum for each column.

# %% [markdown]
# ### Check the data types of the features.

# %%
#checking the datatype of the features.
data_types = df.dtypes
data_types
# Out:
# id                     object
# vendor_id               int64
# pickup_datetime        object
# dropoff_datetime       object
# passenger_count         int64
# pickup_longitude      float64
# pickup_latitude       float64
# dropoff_longitude     float64
# dropoff_latitude      float64
# store_and_fwd_flag     object
# trip_duration           int64
# dtype: object

# %% [markdown]
# By using df.dtypes function we get datatype of each feature (or) column of the dataset, we can see that there are 4 object data types,4 float data types and 2 int datatypes in the data.

# %% [markdown]
# ### Handle missing or erroneous data.

# %%
# Check for missing values
missing_values = df.isnull().sum()
print(missing_values)
# Out:
# id                    0
# vendor_id             0
# pickup_datetime       0
# dropoff_datetime      0
# passenger_count       0
# pickup_longitude      0
# pickup_latitude       0
# dropoff_longitude     0
# dropoff_latitude      0
# store_and_fwd_flag    0
# trip_duration         0
# dtype: int64

# %% [markdown]
# By using df.isnull().sum() we get the number of null values in each column. In this dataset there are no null values in all the columns.

# %% [markdown]
# ### Convert categorical data to numerical values where necessary.

# %%
df['store_and_fwd_flag'] = df['store_and_fwd_flag'].replace( {'N': 0, 'Y': 1})
df.dtypes
df.head()
# Out:
#                 id  vendor_id      pickup_datetime     dropoff_datetime  \
# 1105621  id3077574          2  2016-05-13 08:45:14  2016-05-13 08:50:11
# 906647   id2660233          1  2016-04-21 09:21:30  2016-04-21 09:24:58
# 457894   id2990246          2  2016-01-07 22:17:27  2016-01-07 22:28:19
# 1427706  id1330110          1  2016-05-03 19:27:47  2016-05-03 19:42:26
# 79507    id2910334          2  2016-06-04 15:00:27  2016-06-04 15:15:23
#
#          passenger_count  pickup_longitude  pickup_latitude  \
# 1105621                6        -73.992958        40.768280
# 906647                 1        -73.987854        40.747585
# 457894                 6        -73.985512        40.735691
# 1427706                1        -73.997704        40.741165
# 79507                  1        -73.978264        40.752213
#
#          dropoff_longitude  dropoff_latitude  store_and_fwd_flag  \
# 1105621         -73.981155         40.779301                   0
# ...

# %% [markdown]
# ### Normalize or standardize numerical features if required.

# %%
from sklearn.preprocessing import MinMaxScaler
features = ['pickup_longitude', 'pickup_latitude', 'dropoff_longitude', 'dropoff_latitude','trip_duration']
df[features] =MinMaxScaler().fit_transform(df[features])
df.head()
# Out:
#                 id  vendor_id      pickup_datetime     dropoff_datetime  \
# 1105621  id3077574          2  2016-05-13 08:45:14  2016-05-13 08:50:11
# 906647   id2660233          1  2016-04-21 09:21:30  2016-04-21 09:24:58
# 457894   id2990246          2  2016-01-07 22:17:27  2016-01-07 22:28:19
# 1427706  id1330110          1  2016-05-03 19:27:47  2016-05-03 19:42:26
# 79507    id2910334          2  2016-06-04 15:00:27  2016-06-04 15:15:23
#
#          passenger_count  pickup_longitude  pickup_latitude  \
# 1105621                6          0.911950         0.906534
# 906647                 1          0.912972         0.902575
# 457894                 6          0.913441         0.900300
# 1427706                1          0.911000         0.901347
# 79507                  1          0.914893         0.903460
#
#          dropoff_longitude  dropoff_latitude  store_and_fwd_flag  \
# 1105621           0.904367          0.908641                   0
# ...

# %% [markdown]
# ### Look for errors or outliers in the data

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(8, 5))
sns.boxplot(x=df['passenger_count'])
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(x=df['pickup_longitude'])
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(x=df['pickup_latitude'])
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(x=df['dropoff_longitude'])
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(x=df['dropoff_latitude'])
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(x=df['trip_duration'])
plt.show()

# %% [markdown]
# # 2.Discovering Relationships:

# %% [markdown]
# ### correlation analysis

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10, 7))
sns.heatmap(df.corr(), annot=True, cmap="Reds")
plt.title("Correlation_Heatmap")
plt.show()
# Out:
# /var/folders/d1/st9yxv2j7xgbqdbzvsrz431w0000gn/T/ipykernel_72314/2776762446.py:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot=True, cmap="Reds")

# %% [markdown]
# The trip_duration had a stronger positive correlation with  pickup_longitude than other features with 0.071 positive correlation, The trip_duration increases when the pickup_longitude will increase.
#
# The trip_duration has positive correlation with passenger_count,vendor_id,drop_longitude and store_and_fwd_flag, The trip_duration increases when the positive correlated features will increase.
#
# The trip_duration had a stronger negative correlation with  pickup_latitude than dropoff_latitude with -0.044 negative correlation, The trip_duration decreases when the pickup_longitude will increase.
#
# The pickup_latitude has a  high positive correlation with dropoff_latitude with positive correlation among all features, the pickup_latitude will increase when dropoff_latitude is increased.
#
# The trip_duration had a stronger negative correlation with  dropoff_longitude than any other feature with -0.044 negative correlation.

# %%
df.corr()
# Out:
# /var/folders/d1/st9yxv2j7xgbqdbzvsrz431w0000gn/T/ipykernel_72314/1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                     vendor_id  passenger_count  pickup_longitude  \
# vendor_id            1.000000         0.286771          0.015250
# passenger_count      0.286771         1.000000          0.001933
# pickup_longitude     0.015250         0.001933          1.000000
# pickup_latitude     -0.000773        -0.010586          0.002637
# dropoff_longitude    0.007514        -0.002347          0.388205
# dropoff_latitude     0.004936        -0.006653          0.134963
# store_and_fwd_flag  -0.079918        -0.021463          0.018368
# trip_duration        0.034668         0.009061          0.070830
#
# ...

# %% [markdown]
# ### regression analysis

# %%
import statsmodels.api as sm
y = df['trip_duration']
X = df[['passenger_count','pickup_longitude', 'pickup_latitude', 'dropoff_longitude', 'dropoff_latitude']]
X = sm.add_constant(X)
model = sm.OLS(y, X).fit()
summary = model.summary()
summary
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:          trip_duration   R-squared:                       0.008
# Model:                            OLS   Adj. R-squared:                  0.008
# Method:                 Least Squares   F-statistic:                     167.9
# Date:                Fri, 17 Nov 2023   Prob (F-statistic):          1.99e-178
# Time:                        23:28:37   Log-Likelihood:             1.9384e+05
# No. Observations:              100000   AIC:                        -3.877e+05
# Df Residuals:                   99994   BIC:                        -3.876e+05
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %% [markdown]
# ### creating new features

# %%
import pandas as pd
from geopy.distance import geodesic
df['distance'] = df.apply(lambda row: geodesic((row['pickup_latitude'], row['pickup_longitude']),
                                                  (row['dropoff_latitude'], row['dropoff_longitude'])).km, axis=1)
df.head()
# Out:
#                 id  vendor_id      pickup_datetime     dropoff_datetime  \
# 1105621  id3077574          2  2016-05-13 08:45:14  2016-05-13 08:50:11
# 906647   id2660233          1  2016-04-21 09:21:30  2016-04-21 09:24:58
# 457894   id2990246          2  2016-01-07 22:17:27  2016-01-07 22:28:19
# 1427706  id1330110          1  2016-05-03 19:27:47  2016-05-03 19:42:26
# 79507    id2910334          2  2016-06-04 15:00:27  2016-06-04 15:15:23
#
#          passenger_count  pickup_longitude  pickup_latitude  \
# 1105621                6          0.911950         0.906534
# 906647                 1          0.912972         0.902575
# 457894                 6          0.913441         0.900300
# 1427706                1          0.911000         0.901347
# 79507                  1          0.914893         0.903460
#
#          dropoff_longitude  dropoff_latitude  store_and_fwd_flag  \
# 1105621           0.904367          0.908641                   0
# ...

# %%
df['speed'] = df['distance'] / (df['trip_duration'] / 3600)
df.head()
# Out:
#                 id  vendor_id      pickup_datetime     dropoff_datetime  \
# 1105621  id3077574          2  2016-05-13 08:45:14  2016-05-13 08:50:11
# 906647   id2660233          1  2016-04-21 09:21:30  2016-04-21 09:24:58
# 457894   id2990246          2  2016-01-07 22:17:27  2016-01-07 22:28:19
# 1427706  id1330110          1  2016-05-03 19:27:47  2016-05-03 19:42:26
# 79507    id2910334          2  2016-06-04 15:00:27  2016-06-04 15:15:23
#
#          passenger_count  pickup_longitude  pickup_latitude  \
# 1105621                6          0.911950         0.906534
# 906647                 1          0.912972         0.902575
# 457894                 6          0.913441         0.900300
# 1427706                1          0.911000         0.901347
# 79507                  1          0.914893         0.903460
#
#          dropoff_longitude  dropoff_latitude  store_and_fwd_flag  \
# 1105621           0.904367          0.908641                   0
# ...

# %%
df['pickup_datetime'] = pd.to_datetime(df['pickup_datetime']) #feature 3
df['day_of_week'] = df['pickup_datetime'].dt.dayofweek
df['hour_of_day'] = df['pickup_datetime'].dt.hour
df.head()
# Out:
#                 id  vendor_id     pickup_datetime     dropoff_datetime  \
# 1105621  id3077574          2 2016-05-13 08:45:14  2016-05-13 08:50:11
# 906647   id2660233          1 2016-04-21 09:21:30  2016-04-21 09:24:58
# 457894   id2990246          2 2016-01-07 22:17:27  2016-01-07 22:28:19
# 1427706  id1330110          1 2016-05-03 19:27:47  2016-05-03 19:42:26
# 79507    id2910334          2 2016-06-04 15:00:27  2016-06-04 15:15:23
#
#          passenger_count  pickup_longitude  pickup_latitude  \
# 1105621                6          0.911950         0.906534
# 906647                 1          0.912972         0.902575
# 457894                 6          0.913441         0.900300
# 1427706                1          0.911000         0.901347
# 79507                  1          0.914893         0.903460
#
#          dropoff_longitude  dropoff_latitude  store_and_fwd_flag  \
# 1105621           0.904367          0.908641                   0
# ...

# %%
df['pickup_datetime'] = pd.to_datetime(df['pickup_datetime'])
df['hour_of_day'] = df['pickup_datetime'].dt.hour
df['time_of_day'] = pd.cut(df['hour_of_day'], bins=[0, 6, 12, 18, 24], labels=['Night', 'Morning', 'Afternoon', 'Evening'])
df.head()
# Out:
#                 id  vendor_id     pickup_datetime     dropoff_datetime  \
# 1105621  id3077574          2 2016-05-13 08:45:14  2016-05-13 08:50:11
# 906647   id2660233          1 2016-04-21 09:21:30  2016-04-21 09:24:58
# 457894   id2990246          2 2016-01-07 22:17:27  2016-01-07 22:28:19
# 1427706  id1330110          1 2016-05-03 19:27:47  2016-05-03 19:42:26
# 79507    id2910334          2 2016-06-04 15:00:27  2016-06-04 15:15:23
#
#          passenger_count  pickup_longitude  pickup_latitude  \
# 1105621                6          0.911950         0.906534
# 906647                 1          0.912972         0.902575
# 457894                 6          0.913441         0.900300
# 1427706                1          0.911000         0.901347
# 79507                  1          0.914893         0.903460
#
#          dropoff_longitude  dropoff_latitude  store_and_fwd_flag  \
# 1105621           0.904367          0.908641                   0
# ...

# %% [markdown]
# # 3. Data Visualization:

# %% [markdown]
# ### the distribution of key features.

# %%
sns.pairplot(df[features],diag_kind="kde")

# %%
plt.title("Distribution of passenger_count")
plt.hist(df['passenger_count'], bins=10, label='Histogram by matplotlib')
plt.show()

# %% [markdown]
# In the total number of trips with the passenger_count 1 has a maximum number of trips and the trips with passenger_count 4 is less.

# %%
plt.title("Distribution of trip_duration")
plt.hist(df['trip_duration'], bins=10, label='Histogram by matplotlib')
plt.show()

# %% [markdown]
# In most of the trips the  trip_duration lies between 0 to 0.2.

# %%
plt.title("Distribution of distance")
plt.hist(df['distance'], bins=10, label='Histogram by matplotlib')
plt.show()

# %% [markdown]
# In all the trips the distance lies between 0 to 20.

# %%
plt.title("Distribution of pickup_latitude")
plt.hist(df['pickup_latitude'], bins=10, label='Histogram by matplotlib')
plt.show()

# %% [markdown]
# In all the trips the pickup_latitude lies above 0.8.

# %%
plt.figure(figsize=(8, 5))
sns.countplot(x='time_of_day', data=df, order=['Night', 'Morning', 'Afternoon', 'Evening'], palette='pastel')
plt.title('Distribution of Time of Day')
plt.show()

# %% [markdown]
# Most of the trips are in the afternoon and less trips are at night.

# %%
plt.title("Distribution of pickup_longitude")
plt.hist(df['pickup_longitude'], bins=10, label='Histogram by matplotlib')
plt.show()

# %%
plt.title("Distribution of dropoff_longitude")
plt.hist(df['dropoff_longitude'], bins=10, label='Histogram by matplotlib')
plt.show()

# %% [markdown]
# ### the relationship between different features and the trip duration

# %%
sns.scatterplot(x="distance", y="trip_duration", data=df, size=8)
plt.title("distance vs. Trip Duration")
# Out:
# Text(0.5, 1.0, 'distance vs. Trip Duration')

# %%
sns.scatterplot(x="pickup_longitude", y="trip_duration", data=df, size=8)
plt.title("Pickup Longitude vs. Trip Duration")
# Out:
# Text(0.5, 1.0, 'Pickup Longitude vs. Trip Duration')

# %%
sns.scatterplot(x="passenger_count", y="trip_duration", data=df, size=8)
plt.title("passenger_count vs. Trip Duration")
# Out:
# Text(0.5, 1.0, 'passenger_count vs. Trip Duration')

# %% [markdown]
# The trip duration is high with 1 passenger.
# The trip duration is low with 4 passengers.

# %%
sns.scatterplot(x="pickup_latitude", y="trip_duration", data=df, size=8)
plt.title("pickup_latitude vs. Trip Duration")
# Out:
# Text(0.5, 1.0, 'pickup_latitude vs. Trip Duration')

# %%
sns.scatterplot(x="speed", y="trip_duration", data=df, size=8)
plt.title(" speed vs. Trip Duration")
# Out:
# Text(0.5, 1.0, ' speed vs. Trip Duration')

# %%
sns.scatterplot(x="time_of_day", y="trip_duration", data=df, size=8)
plt.title(" time_of_day vs. Trip Duration")
# Out:
# Text(0.5, 1.0, ' time_of_day vs. Trip Duration')

# %%
sns.scatterplot(x="dropoff_longitude", y="trip_duration", data=df, size=8)
plt.title("dropoff_longitude vs. Trip Duration")
# Out:
# Text(0.5, 1.0, 'dropoff_longitude vs. Trip Duration')

# %%
sns.scatterplot(x="pickup_longitude", y="trip_duration", data=df, size=8)
plt.title("Pickup Longitude vs. Trip Duration")
# Out:
# Text(0.5, 1.0, 'Pickup Longitude vs. Trip Duration')

# %% [markdown]
# ### Employ geographic visualizations to represent pickup and drop-off location

# %%
import folium
pickup_dropoff_map = folium.Map(location=[df['pickup_latitude'].mean(), df['pickup_longitude'].mean()], zoom_start=10)
pickup_locations = folium.FeatureGroup(name='Pickup Locations')
dropoff_locations = folium.FeatureGroup(name='Drop-off Locations')
for index, row in df.iterrows():
    pickup_location = [row['pickup_latitude'], row['pickup_longitude']]
    dropoff_location = [row['dropoff_latitude'], row['dropoff_longitude']]
    folium.CircleMarker(
        location=pickup_location,
        radius=5,
        color='blue',
        fill=True,
    ).add_to(pickup_locations)
    folium.CircleMarker(
        location=dropoff_location,
        radius=5,
        color='red',
        fill=True,
    ).add_to(dropoff_locations)
    folium.PolyLine([pickup_location, dropoff_location], color='green').add_to(pickup_dropoff_map)
pickup_locations.add_to(pickup_dropoff_map)
dropoff_locations.add_to(pickup_dropoff_map)
folium.LayerControl().add_to(pickup_dropoff_map)
pickup_dropoff_map

# %% [markdown]
# # 4.Algorithm and Data Structure Efficiency

# %% [markdown]
# Linkedlist data structure is the best data structure for insertions of new elements at the end of sorted list without the need to shift existing element and more efficient in sorting data.
# The nodes in a linked list contain references to the elements that comes after it, it is easy to maintain in  the sorted order.
# When new trips are added frequently, appending to the end of a linked list has a constant time complexity, O(1).
# linkedlist are dynamic in size where there is no limit on the number elements are inserted in the list.
# Linked lists can be easily sorted by adjusting the links between nodes without the need for data movement.
# where the size of the dataset is not known before the time, linked lists may be more memory-efficient than arrays.
# Each new node in a linked list is placed separately, and the entire data does not need to be shifted.

# %%
#example of LinkedList 
class Node:
    def __init__(self,data,trip):
        self.data = data
        self.trip = trip
        self.next = None

class LinkedList:
    def __init__(self):
        self.head = None

    def insert(self,data,trip):
        new_node =Node(data,trip)
        if not self.head or data < self.head.data:
            new_node.next = self.head
            self.head = new_node
        else:
            n = self.head
            while n.next and n.next.data <= data:
                n = n.next
            new_node.next = n.next
            n.next = new_node

    def display(self):
        n = self.head
        while n:
            print(f"trip duration in mins: {n.data} ,trip: {n.trip}")
            n = n.next

sorted_trips = LinkedList()
sorted_trips.insert(30,"1")
sorted_trips.insert(26,"2")
sorted_trips.insert(43,"3")
sorted_trips.display()

# %% [markdown]
# When new data (a phone number) is added and a goal is to fast filter trips by specific passenger, hash tables perform well.
#
# Hash tables are good for obtaining data based on a given key because they offer constant-time average-case complexity for search operations without looking the entire data.
#
# Hash table provides uniqueness in keys as there no same phone numbers in the data and provides the data of the phone number.
#
# The Hash Table allows for direct access to the data associated with a specific phone number
#
# when data is updated frequently or new trips are added for various passengers, hash tables work well.

# %%
class Hash:
    def __init__(self,data,trip, phone_number):
        self.data = data
        self.trip = trip
        self.phone_number = phone_number

class PhoneNumber:
    def __init__(self):
        self.trips = {}

    def insert(self, data, trip, phone_number):
        new_node = Hash(data, trip, phone_number)
        if phone_number not in self.trips:
            self.trips[phone_number] = []
        self.trips[phone_number].append(new_node)

    def phone_number(self, phone_number):
        return self.trips.get(phone_number, [])
    

p= PhoneNumber()
p.insert(30, "1", "9390691699")
p.insert(26, "2", "9056740911")
p.insert(43, "3", "6720975633")

data_of_phone_number = p.phone_number("9390691699")
for tri in data_of_phone_number:
    print(f"trip duration in mins: {tri.data}, trip: {tri.trip}")
